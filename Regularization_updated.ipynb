# %% [markdown]
# # -Underfitting = When model is too simple
# # -Overfitting = The model trained too much in one field
#
# ## variance: high variance overfitting
# ## bias: high bias underfitting

# %% [markdown]
# # Solving Underfitting
# ## - make data more complex
# ## - add new features
#
# # Solving Overfitting
# ## -make data less complex
# ## -regularization
# ### L1 (Lasso Regression)
# ![image.png](data:image/png;base64,...)
# ### L2 (Ridge Regression )
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
from sklearn.linear_model import Ridge, LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
data = pd.read_csv("train.csv")

# %%
X = data.drop('SalePrice',axis=1)
y = data.loc[:,'SalePrice']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %% [markdown]
# # Ridge Regressions Compare

# %%
linear_reg = LinearRegression()
ridge_reg = Ridge(alpha=0.05, normalize=True)

# %% [markdown]
# # In Python Alpha Refers to λ

# %%
linear_reg.fit(X_train, y_train)
ridge_reg.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_base.py:145: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   FutureWarning,
# Ridge(alpha=0.05, normalize=True)

# %%
linear_pred = linear_reg.predict(X_test)
ridge_pred = ridge_reg.predict(X_test)

# %%
linear_mse = mean_squared_error(y_test, linear_pred)
ridge_mse = mean_squared_error(y_test, ridge_pred)

# %%
print(f"MSE without Ridge: {linear_mse}")
print(f"MSE with Ridge : {ridge_mse}")
# Out:
# MSE without Ridge: 2180526147.352007
# MSE with Ridge : 2176174082.8230476
